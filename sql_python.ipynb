# %%
import pandas as pd
from sqlalchemy import create_engine


# Replace with your actual database connection details
database_uri = "mysql://root:Likhith1234@localhost:3306/mavenmovies"

# Create an SQLAlchemy engine
engine = create_engine(database_uri)

# Write your SQL query
query = "" #write a query here

# Use the engine to connect to the database and fetch the data with pandas
pandas_dataframe = pd.read_sql(query, con=engine)

# %%
pandas_dataframe
# Out:
#    customer_id first_name last_name
# 0            1       MARY     SMITH
# 1            2   PATRICIA   JOHNSON
# 2            3      LINDA  WILLIAMS
# 3            4    BARBARA     JONES
# 4            5  ELIZABETH     BROWN
# 5            6   JENNIFER     DAVIS
# 6            7      MARIA    MILLER
# 7            8      SUSAN    WILSON
# 8            9   MARGARET     MOORE
# 9           10    DOROTHY    TAYLOR

# %%
query = "select count(film_id) from film where replacement_cost>15 and replacement_cost<20"

# Use the engine to connect to the database and fetch the data with pandas
pandas_dataframe = pd.read_sql(query, con=engine)

# %%
pandas_dataframe
# Out:
#    count(film_id)
# 0             214

# %%
query = "select min(rental_duration) from film"

# Use the engine to connect to the database and fetch the data with pandas
pandas_dataframe = pd.read_sql(query, con=engine)

# %%
pandas_dataframe
# Out:
#    min(rental_duration)
# 0                     3

# %%
query = "select city,country_id from city where country_id=44"

# Use the engine to connect to the database and fetch the data with pandas
pandas_dataframe = pd.read_sql(query, con=engine)
pandas_dataframe
# Out:
#                        city  country_id
# 0                     Adoni          44
# 1                Ahmadnagar          44
# 2     Allappuzha (Alleppey)          44
# 3                  Ambattur          44
# 4                    Amroha          44
# 5                 Balurghat          44
# 6   Berhampore (Baharampur)          44
# 7                 Bhavnagar          44
# 8                  Bhilwara          44
# 9                Bhimavaram          44
# 10                   Bhopal          44
# 11                 Bhusawal          44
# 12                  Bijapur          44
# 13               Chandrapur          44
# 14                   Chapra          44
# 15           Dhule (Dhulia)          44
# 16                   Etawah          44
# 17                Firozabad          44
# 18              Gandhinagar          44
# 19                 Gulbarga          44
# 20                   Haldia          44
# 21                Halisahar          44
# ...

# %%
query = "select concat(first_name,' ',last_name) as full_name, address,st.store_id from store st join staff sf on st.store_id=sf.store_id join address a on a.address_id=sf.address_id"

# Use the engine to connect to the database and fetch the data with pandas
pandas_dataframe = pd.read_sql(query, con=engine)
pandas_dataframe
# Out:
#       full_name               address  store_id
# 0  Mike Hillyer     23 Workhaven Lane         1
# 1  Jon Stephens  1411 Lillydale Drive         2

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\MySQLdb\cursors.py:200, in BaseCursor._mogrify(self, query, args)
#     199 try:
# --> 200     query = query % args
#     201 except TypeError as m:
#
# TypeError: not enough arguments for format string
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# ...

# %%
query = "select distinct title,description,s.store_id from film f join inventory i on f.film_id=i.film_id join store s on s.store_id=i.store_id  where s.store_id=2"

# Use the engine to connect to the database and fetch the data with pandas
pandas_dataframe = pd.read_sql(query, con=engine)
pandas_dataframe
# Out:
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1       ACE GOLDFINGER  A Astounding Epistle of a Database Administrat...
# 2     ADAPTATION HOLES  A Astounding Reflection of a Lumberjack And a ...
# 3     AFFAIR PREJUDICE  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 757     WRONG BEHAVIOR  A Emotional Saga of a Crocodile And a Sumo Wre...
# 758        YENTL IDAHO  A Amazing Display of a Robot And a Astronaut w...
# 759       ZHIVAGO CORE  A Fateful Yarn of a Composer And a Man who mus...
# 760  ZOOLANDER FICTION  A Fateful Reflection of a Waitress And a Boat ...
# 761          ZORRO ARK  A Intrepid Panorama of a Mad Scientist And a B...
#
#      store_id
# 0           2
# 1           2
# 2           2
# 3           2
# ...
